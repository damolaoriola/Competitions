# %%
import pandas as pd
df_json = pd.read_json('540_hexclusters.json', orient = 'values')

# %%
df_json
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 1    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 2    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 3    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 4    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 5    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 6    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 7    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 8    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 9    FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 10   FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# 11   FeatureCollection  {'type': 'Feature', 'properties': {'MOVEMENT_I...
# ...
